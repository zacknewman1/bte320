# %%
6//4
# Out:
# 1

# %%
6.0//4
# Out:
# 1.0

# %%
2**3
# Out:
# 8

# %%
5%3
# Out:
# 2

# %%
3%4
# Out:
# 3

# %%
3.14*(3**2)
# Out:
# 28.26

# %% [markdown]
# WEEK 2 NOTES

# %%
# Define the principal amount
principal = 3000

# Define the annual interest rate (as a decimal)
rate = 0.03

# Define the number of times interest is compounded per year (annually in this case)
n = 1

# Define the number of years the money is invested or borrowed for
t = 1 # Assuming 1 year initially, you can change this value

# Calculate the future value (A) using the compound interest formula: A = P(1 + r/n)^(nt)
amount = principal * (1 + rate / n)**(n * t)

# Calculate the compound interest
compound_interest = amount - principal

print(f"Principal: ${principal:.2f}")
print(f"Annual Interest Rate: {rate*100:.0f}%")
print(f"Time (years): {t}")
print(f"Future Value (Amount): ${amount:.2f}")
print(f"Compound Interest Earned: ${compound_interest:.2f}")
# Out:
# Principal: $3000.00
# Annual Interest Rate: 3%
# Time (years): 1
# Future Value (Amount): $3090.00
# Compound Interest Earned: $90.00

# %%
interest = 3 # The interest in absolute value (3%)
principal = 3000 # The initial amount of money on the account
n = 1 # The number of years

final = principal * (1+interest/100)**n

print(final)
# Out:
# 3090.0

# %%
print(interest, principal)
# Out:
# 3 3000

# %%
print("interest rate", interest, sep="=>")
print("number of years:", n)
# Out:
# interest rate=>3
# number of years: 1

# %%
print("interest rate:", interest, end="---")
print("number of years:", n)
# Out:
# interest rate: 3---number of years: 1

# %%
print("interest rate:", interest, sep=">>>", end="&&&")
print("Number of years =", n)
# Out:
# interest rate:>>>3&&&Number of years = 1

# %%
print("interest rate:", interest, "; Number of years =", n)
# Out:
# interest rate: 3 ; Number of years = 1

# %%
"interest rate: {}; number of years = {}".format(interest, n)
# Out:
# 'interest rate: 3; number of years = 1'

# %%
interest = 3
print(f"Interest rate: {interest}; Number of years = {n}")
# Out:
# Interest rate: 3; Number of years = 1

# %%
interest = float(input("set interest value (%):"))
principal = float(input("enter initial amount on the account ($):"))
n = int(input("enter number of years:"))
final = principal * (1+interest/100)**n
print(f"total amount after {n} year(s): {final}$")
# Out:
# set interest value (%):3
# enter initial amount on the account ($):3000
# enter number of years:1
# total amount after 1 year(s): 3090.0$

# %% [markdown]
# input returns a string by default, wrap function around to change (float, bool, etc.)

# %% [markdown]
# in class assignment 1

# %%
sales = float(input("enter the total sales:"))
print(sales)
COGS = float(input("enter the total COGS:"))
print(COGS)
GP = sales - COGS
print(GP)
net = GP - taxes
taxes = GP * 0.3
print(taxes)
print(net)
# Out:
# enter the total sales:12000
# 12000.0
# enter the total COGS:4800
# 4800.0
# 7200.0
# 2160.0
# 5040.0

# %%
sales = float(input("enter the total sales ($):"))
cogs = .4 * sales
gross_profit = sales - cogs
print(f"Sales: {sales}$")
print(f"COGS: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# enter the total sales ($):12000
# Sales: 12000.0$
# COGS: 4800.0$
# Gross Profit: 7200.0$

# %% [markdown]
# WEEK 3 NOTES

# %%
email = "receive your award!!!"
is_urgent = "URGENT"
has_www = "www"
if is_urgent in email:
  print("phishing")
elif has_www in email:
  print("Spam")
else:
  print("legit")
# Out:
# legit

# %%
if condition:
  exprs
  exprs
elif another_condition:
    exprs
    exprs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2394884436.py in <cell line: 0>()
# ----> 1 if condition:
#       2   exprs
#       3   exprs
#       4 elif another_condition:
#       5     exprs
#
# NameError: name 'condition' is not defined

# %%
grade = float(input("Enter student grade (0-100):"))
if grade >= 97:
  print("A+")
elif grade >= 93:
  print("A")
# Out:
# Enter student grade (0-100):95
# A

# %%
email = "URGENT!! Click on the following: www.phish.org to..."
is_urgent = "URGENT"
has_www = "www."
if is_urgent in email:
  if has_www in email:
    print("phishing")
  else:
    print("spam")
else:
  print("legit")
# Out:
# phishing

# %%
email = "URGENT!!! Click on the following: to..."
is_urgent = "URGENT"
has_www = "www."
if (is_urgent in email) and (has_www in email):
  print("phishing")
if (is_urgent in email) and not (has_www in email):
  print("spam")
else:
  print("legit")

# %%
email = "URGENT!!! Click on the following: to..."
is_urgent = "URGENT"
has_www = "www."
if (is_urgent in email) and (has_www in email):
  print("phishing")
elif is_urgent in email:
  print("spam")
else:
  print("legit")

# %%
x = 3
if x % 2 == 0:
  print(x, "is even")
else:
  print(x, "is odd")
# Out:
# 10 is even

# %%
x = 3
if x % 2 == 0:
  print(x, "is even")
elif x % 2 ! = 0:
  print(x, "is odd")

# %%
print("even" if x % 2 == 0 else "odd")

# %%
number1 = float(input("Enter the first number: "))
operator = input("Enter an operator (+, -, *, /): ")
number2 = float(input("Enter the second number: "))
if operator == "+":
  result = number1 + number2
elif operator == "-":
  result = number1 - number2
elif operator == "*":
  result = number1 * number2
elif operator == "/":
  result = number1 / number2
print(result)
# Out:
# Enter the first number: 14.3
# Enter an operator (+, -, *, /): -
# Enter the second number: 2
# 12.3
