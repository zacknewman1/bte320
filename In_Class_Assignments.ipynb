# %% [markdown]
# <a href="https://colab.research.google.com/github/zacknewman1/bte320/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("enter the total sales:"))
print(sales)
COGS = float(input("enter the total COGS:"))
print(COGS)
GP = sales - COGS
print(GP)
taxes = GP * 0.3
print(taxes)
net = GP - taxes
print(net)
# Out:
# enter the total sales:12000
# 12000.0
# enter the total COGS:4800
# 4800.0
# 7200.0
# 2160.0
# 5040.0

# %%
sales = float(input("enter the total sales ($):"))
cogs = .4 * sales
gross_profit = sales - cogs
print(f"Sales: {sales}$")
print(f"COGS: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# enter the total sales ($):12000
# Sales: 12000.0$
# COGS: 4800.0$
# Gross Profit: 7200.0$
